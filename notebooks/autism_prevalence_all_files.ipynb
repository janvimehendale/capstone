# %% [markdown]
# # Analyzing the Autism Prevalence

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime

# %% [markdown]
# Read csv files to Dataframe

# %% [markdown]
# CSV 1

# %%
# Read Autism prevalance around the world
asd_world = pd.read_csv("../data/autism_prevalence_studies.csv")
asd_world.head()
# Out:
#          Author                                              Title  \
# 0        Lotter  Epidemiology of Autistic Conditions in Young C...
# 1      Treffert                   Epidemiology of infantile Autism
# 2         Brask  A Prevalence investigation of Childhood Psychoses
# 3  Wing, et al.  The prevalence of early childhood autism: comp...
# 4  Wing, et al.  Severe impairments of social interaction and a...
#
#    Year Published  Country              Area(s) Age Range Study Years  \
# 0            1966  England  County of Middlesex   8 to 10        1964
# 1            1970      USA            Wisconsin   2 to 12   1962-1967
# 2            1972  Denmark        Åarhus County   2 to 14        1962
# 3            1976  England           Camberwall   5 to 14        1974
# 4            1979  England           Camberwell   0 to 14        1970
#
#                  Case Identification Method                   Case Criterion  \
# ...

# %%
asd_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 26 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Author                                            207 non-null    object
#  1   Title                                             207 non-null    object
#  2   Year Published                                    207 non-null    int64
#  3   Country                                           207 non-null    object
#  4   Area(s)                                           202 non-null    object
#  5   Age Range                                         202 non-null    object
#  6   Study Years                                       185 non-null    object
#  7   Case Identification Method                        207 non-null    object
#  8   Case Criterion                                    207 non-null    object
# ...

# %%
asd_world_count =  asd_world.groupby('Country')['Number of Cases'].sum().sort_values(ascending=False).reset_index()
asd_world_count.head()
# Out:
#    Country  Number of Cases
# 0      USA         745934.0
# 1  England         121913.0
# 2   Sweden          43888.0
# 3    Korea          35529.0
# 4   Canada          23330.0

# %%
# Read Cumulative Incidence Data
cumulative_incidence = pd.read_csv("../data/Cumulative Incidence Data.csv")
cumulative_incidence.head()
# Out:
#    Year    State  Months  Year Born  Cumulative Incidence   LI        UI
# 0  2022  Arizona       1       2014                   0.0  0.0  0.572255
# 1  2022  Arizona       2       2014                   0.0  0.0  0.572255
# 2  2022  Arizona       3       2014                   0.0  0.0  0.572255
# 3  2022  Arizona       4       2014                   0.0  0.0  0.572255
# 4  2022  Arizona       5       2014                   0.0  0.0  0.572255

# %%
# Read Confidence Interval
confidence_interval = pd.read_csv("../data/Estimates for overall ASD prevalence in US over time with or without confidence interval__p_.csv")
confidence_interval.head()
# Out:
#      State  Denominator  Prevalence Estimates per 1,000 Children  Lower CI  \
# 0  Alabama      35472.0                                      3.3       2.7
# 1  Alabama      11676.0                                      4.6       3.5
# 2  Alabama      35126.0                                      6.0       5.3
# 3  Alabama      36566.0                                      4.8       4.1
# 4  Alabama      21833.0                                      5.7       4.8
#
#    Upper CI Prevalence Range Show Lower and Upper CI  Year       Data Set
# 0       3.9              <10                     Yes  2002  ADDM Network*
# 1       6.0              <10                     Yes  2004  ADDM Network*
# 2       6.9              <10                     Yes  2006  ADDM Network*
# 3       5.5              <10                     Yes  2008  ADDM Network*
# 4       6.8              <10                     Yes  2010  ADDM Network*

# %%
# Read Prevalence Estimates by Geographic Area
geography = pd.read_csv("../data/Prevalence Estimates by Geographic Area.csv")
geography.head()
# Out:
#      State  Denominator  Prevalence Estimates per 1,000 Children  Lower CI  \
# 0  Alabama      35472.0                                      3.3       2.7
# 1  Alabama      11676.0                                      4.6       3.5
# 2  Alabama      35126.0                                      6.0       5.3
# 3  Alabama      36566.0                                      4.8       4.1
# 4  Alabama      21833.0                                      5.7       4.8
#
#    Upper CI Prevalence Range Show Lower and Upper CI  Year       Data Set
# 0       3.9              <10                     Yes  2002  ADDM Network*
# 1       6.0              <10                     Yes  2004  ADDM Network*
# 2       6.9              <10                     Yes  2006  ADDM Network*
# 3       5.5              <10                     Yes  2008  ADDM Network*
# 4       6.8              <10                     Yes  2010  ADDM Network*

# %%
# Read Prevalence Estimates by Race_Ethnicity
ethnicity = pd.read_csv("../data/Prevalence Estimates by Race_Ethnicity.csv")
ethnicity.head()
# Out:
#    Year       State  White  White Lower CI  White Upper CI  Black  \
# 0  2000     Alabama    NaN             NaN             NaN    NaN
# 1  2000     Arizona    8.6             7.5             9.8    7.3
# 2  2000    Arkansas    NaN             NaN             NaN    NaN
# 3  2000  California    NaN             NaN             NaN    NaN
# 4  2000    Colorado    NaN             NaN             NaN    NaN
#
#    Black Lower CI  Black Upper CI  Hispanic  Hispanic Lower CI  \
# 0             NaN             NaN       NaN                NaN
# 1             4.4            12.2       NaN                NaN
# 2             NaN             NaN       NaN                NaN
# 3             NaN             NaN       NaN                NaN
# 4             NaN             NaN       NaN                NaN
#
#    Hispanic Upper CI  Asian or Pacific Islander  \
# 0                NaN                        NaN
# 1                NaN                        NaN
# ...

# %%
# Read Prevalence Estimates by Gender
gender = pd.read_csv("../data/Prevalence Estimates by Sex.csv")
gender.head()
# Out:
#    Year       State  Boys  Boys Lower CI  Boys Upper CI  Girls  \
# 0  2000     Alabama   NaN            NaN            NaN    NaN
# 1  2000     Arizona   9.7            8.5           11.1    3.2
# 2  2000    Arkansas   NaN            NaN            NaN    NaN
# 3  2000  California   NaN            NaN            NaN    NaN
# 4  2000    Colorado   NaN            NaN            NaN    NaN
#
#    Girls Lower CI  Girls Upper CI
# 0             NaN             NaN
# 1             2.5             4.0
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
# Read Prevalence Estimates Over Time
overtime = pd.read_csv("../data/Prevalence Estimates Over Time.csv")
overtime.head()
# Out:
#      State  Denominator  Prevalence Estimates per 1,000 Children  Lower CI  \
# 0  Alabama      35472.0                                      3.3       2.7
# 1  Alabama      11676.0                                      4.6       3.5
# 2  Alabama      35126.0                                      6.0       5.3
# 3  Alabama      36566.0                                      4.8       4.1
# 4  Alabama      21833.0                                      5.7       4.8
#
#    Upper CI Prevalence Range Show Lower and Upper CI  Year       Data Set
# 0       3.9              <10                     Yes  2002  ADDM Network*
# 1       6.0              <10                     Yes  2004  ADDM Network*
# 2       6.9              <10                     Yes  2006  ADDM Network*
# 3       5.5              <10                     Yes  2008  ADDM Network*
# 4       6.8              <10                     Yes  2010  ADDM Network*
